# %% [markdown]
# <a href="https://colab.research.google.com/github/Tulin206/erumhub_deep-learning_2026/blob/main/code/10_vgg_cifar10_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Overview: CIFAR10 Classification with a Custom VGG-like Network
#
# This notebook guides you through building a VGG-style convolutional neural network from scratch to classify images in the CIFAR10 dataset. The workflow includes:
#
# - **Importing Libraries**: Key Python libraries for deep learning, data handling, and visualization.
# - **Loading Data**: CIFAR10 dataset is loaded, containing 60,000 color images across 10 classes.
# - **Preprocessing**: Images are normalized to the [0, 1] range for better model performance.
# - **Visualization**: 25 sample images are displayed with their class names for a quick visual check.
# - **Model Construction**: A VGG-like CNN is built from scratch using TensorFlow/Keras, with multiple convolutional and pooling layers, followed by dense layers.
# - **Training**: The model is trained for 30 epochs on the CIFAR10 data.
# - **Evaluation**: Training progress is visualized with accuracy and loss plots. The model is evaluated on the test set to report accuracy.
# - **Confusion Matrix**: Predictions are made on the test set and a confusion matrix is plotted to show class-wise performance.
#
# This notebook helps learners understand how to design, train, and evaluate deeper CNN architectures for image classification tasks.
#
# ---
#
# ## 🎯 Exercise Instructions
#
# Your task is to implement a **VGG-like network** for CIFAR10 classification. The data loading and preprocessing are provided for you. You need to:
#
# 1. **Build the VGG-like model** - Create a function `build_vgg_like()` with multiple convolutional blocks
# 2. **Compile the model** - Use appropriate optimizer and loss function
# 3. **Train the model** - Train for 30 epochs with batch size 64
# 4. **Evaluate and visualize** - Plot accuracy/loss and create a confusion matrix
#
# Good luck! 💪
#
# ---

# %%
# Import required libraries
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Load the CIFAR10 dataset
(train_images, train_labels), (test_images, test_labels) = keras.datasets.cifar10.load_data()

# %%
# Normalize pixel values to [0, 1]
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
# Define class names for CIFAR10
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# Display 25 sample images
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(train_images[i])
    plt.axis('off')
    plt.title(class_names[train_labels[i,0]])
plt.show()

# %%
# TODO: Build a VGG-like model from scratch
# Create a function called build_vgg_like(input_shape, num_classes)
#
# Architecture hints:
# - Block 1: Conv2D(64) -> Conv2D(64) -> MaxPooling2D
# - Block 2: Conv2D(128) -> Conv2D(128) -> MaxPooling2D
# - Block 3: Conv2D(256) -> Conv2D(256) -> MaxPooling2D
# - Flatten and Dense layers: Dense(512, activation='relu'), Dropout(0.5), Dense(num_classes, activation='softmax')
#
# Parameters for Conv2D: kernel_size=(3,3), activation='relu', padding='same'

def build_vgg_like(input_shape, num_classes):
    """
    Build a VGG-like model for CIFAR10 classification.

    Args:
        input_shape: Shape of input images (e.g., (32, 32, 3))
        num_classes: Number of output classes (10 for CIFAR10)

    Returns:
        A compiled Keras model
    """
    # YOUR CODE HERE
    pass

# %%
# Create the VGG-like model
model = build_vgg_like(train_images.shape[1:], 10)
model.summary()

# %%
# TODO: Compile the model
# Use optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy']

# YOUR CODE HERE

# %%
# TODO: Train the model
# Use 30 epochs, batch_size=64, validation_data=(test_images, test_labels), verbose=2

# YOUR CODE HERE
# history = model.fit(...)

# %%
# TODO: Convert training history to DataFrame

# YOUR CODE HERE
# history_df = pd.DataFrame(history.history)

# %%
# TODO: Plot training and validation accuracy
# Use sns.lineplot with history_df[['accuracy','val_accuracy']]

# YOUR CODE HERE

# %%
# TODO: Plot training and validation loss
# Use sns.lineplot with history_df[['loss','val_loss']]

# YOUR CODE HERE

# %%
# TODO: Evaluate the model on the test set

# YOUR CODE HERE
# test_loss, test_acc = model.evaluate(...)

# %%
# TODO: Predict and show confusion matrix
# Steps:
# 1. Make predictions on test images
# 2. Get predicted class labels using np.argmax()
# 3. Create confusion matrix using confusion_matrix()
# 4. Plot using sns.heatmap()

from sklearn.metrics import confusion_matrix

# YOUR CODE HERE
